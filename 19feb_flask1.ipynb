# %%
import logging

# %%
logging.basicConfig(filename="flask1_txt", level= logging.DEBUG)

# %%
"""Q1. What is Flask Framework? What are the advantages of Flask Framework?"""
# Out:
# 'Q1. What is Flask Framework? What are the advantages of Flask Framework?'

# %%
logging.info("Flask is a web framework. This means flask provides you with tools, libraries and technologies that allow you to build a web application. This web application can be some web pages, a blog, a wiki or go as big as a web-based calendar application or a commercial website.")

# %%
"""Flask is a web framework. This means flask provides you with tools, libraries and technologies that allow you to build a web application. This web application can be some web pages, a blog, a wiki or go as big as a web-based calendar application or a commercial website."""
# Out:
# 'Flask is a web framework. This means flask provides you with tools, libraries and technologies that allow you to build a web application. This web application can be some web pages, a blog, a wiki or go as big as a web-based calendar application or a commercial website.'

# %%
logging.info("Scalable. Size is everything,and Flask's status as a microframework means that you can use it to grow a tech project such as a web app incredibly quickly.2)Flexible 3)Easy to negotiate.4)Lightweight 5)Documentation 6)Not a lot of tools.7)Difficult to get familiar with a larger Flask app. 8)Maintenance costs.")

# %%
"""Scalable.Size is everything,and Flask's status as a microframework means that you can use it to grow a tech project such as a web app incredibly quickly.
Flexible.
Easy to negotiate.
Lightweight. 
Documentation. 
Not a lot of tools.
Difficult to get familiar with a larger Flask app.
Maintenance costs."""
# Out:
# "Scalable.Size is everything,and Flask's status as a microframework means that you can use it to grow a tech project such as a web app incredibly quickly.\nFlexible.\nEasy to negotiate.\nLightweight. \nDocumentation. \nNot a lot of tools.\nDifficult to get familiar with a larger Flask app.\nMaintenance costs."

# %%
"""Q2. Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in
Jupyter Notebook."""
# Out:
# 'Q2. Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in\nJupyter Notebook.'

# %% [markdown]
# ![image.png](attachment:1a7a8114-67cc-4ba3-b6e0-6a7e1bd8c61a.png)

# %% [markdown]
# ![Screenshot (7)](C:\Users\nihar\Pictures\Screenshots)

# %% [markdown]
# #Q3. What is App routing in Flask? Why do we use app routes?

# %%
"""App Routing means mapping the URLs to a specific function that will handle the logic for that URL. Modern web frameworks use more meaningful URLs to help users remember the URLs and make navigation simpler. Example: In our application, the URL (“/”) is associated with the root URL"""
#@app.route("/")
# Out:
# 'App Routing means mapping the URLs to a specific function that will handle the logic for that URL. Modern web frameworks use more meaningful URLs to help users remember the URLs and make navigation simpler. Example: In our application, the URL (“/”) is associated with the root URL'

# %%
#app routes provides route to reach out to function and access it

# %%
"""Q4. Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/”
route to show the following details:
Company Name: ABC Corporation
Location: India
Contact Detail: 999-999-9999
Attach the screenshot of the output in Jupyter Notebook."""
# Out:
# 'Q4. Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/”\nroute to show the following details:\nCompany Name: ABC Corporation\nLocation: India\nContact Detail: 999-999-9999\nAttach the screenshot of the output in Jupyter Notebook.'

# %% [markdown]
# ![image.png](attachment:6d9ab7f6-a8ab-42aa-a538-65ca14dab0fa.png)

# %%
"""Q5. What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the
url_for() function."""
# Out:
# 'Q5. What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the\nurl_for() function.'

# %%
#The url_for() function is used to build a URL to the specific function dynamically.

# %% [markdown]
# ![image.png](attachment:92186c00-b967-4efc-bb2e-9a435517a6b9.png)
